# %% [markdown]
# disciplina-turma-nota<br>
# Perguntas:<br>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from bokeh.plotting import figure, output_notebook, show
from bokeh.layouts import gridplot, row
from bokeh.models.widgets import Tabs, Panel
from bokeh.charts import Line
# %matplotlib inline

# %%
pd_dados = pd.read_csv('turma_professor_notas.csv')
pd_disciplinas = pd.read_csv('disciplinas.csv')

# %% [markdown]
# ## 1) Notas das turmas tem muita diferença entre um mesmo semestre?

# %%
listTabs = []
for index, row in pd_disciplinas.iterrows():
    
    y = pd_dados[pd_dados['nome_disc'] == row['nome_disc']]['reprovados']
    x = []
    for index_disc, row_disc in pd_dados[pd_dados['nome_disc'] == row['nome_disc']].iterrows():
        if (int(row_disc['periodo']) == 1):
            x.append(str(row_disc['ano'])+""+str(0))
        else:
           x.append(str(row_disc['ano'])+""+str(5))
        
    p = figure(plot_width=400, plot_height=300, title=row['nome_disc'], x_axis_label='ano/semestre', y_axis_label='Quant Reprovados')
    p.circle(x, y, fill_color="white", size=12)
    listTabs.append(p)

output_notebook()
grid = gridplot([[ listTabs[0], listTabs[1]],[ listTabs[2], listTabs[3]]])
show(grid)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1e0ca1a1-55a2-4438-8945-a9ed2bcbde21">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b1942cd8-b79a-4aa5-8086-2b8b09cb6a91"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("b1942cd8-b79a-4aa5-8086-2b8b09cb6a91");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b1942cd8-b79a-4aa5-8086-2b8b09cb6a91");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b1942cd8-b79a-4aa5-8086-2b8b09cb6a91' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e28ef784-6bcf-4a2c-a586-5e4a061fd0d7":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"dff7e88a-0e7b-4cf5-be5b-ea301b18d78d","subtype":"Figure","type":"Plot"},"ticker":{"id":"58a6ade1-ae42-4195-a9a9-5f46a549697f","type":"BasicTicker"}},"id":"59dabd98-cf28-4137-bca1-bf27f28f589d","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"1381bde7-f376-4217-b109-2fb40d3ba728","type":"Circle"},{"attributes":{"data_source":{"id":"0b0763cc-3445-4000-825a-417201ade664","type":"ColumnDataSource"},"glyph":{"id":"87ee4f5d-c1b4-4825-984b-c99d572d2f2e","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1381bde7-f376-4217-b109-2fb40d3ba728","type":"Circle"},"selection_glyph":null},"id":"ee93ffb0-7a17-44da-bc8d-a4ce2f492e1c","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"87ee4f5d-c1b4-4825-984b-c99d572d2f2e","type":"Circle"},{"attributes":{},"id":"975ccfb3-b366-405b-8d79-dac373c276d5","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"41c37ec7-9f06-413e-ac58-69f9b27c6372","type":"BoxAnnotation"},{"attributes":{"axis_label":"ano/semestre","formatter":{"id":"4d25d171-4e70-4885-889a-b84a4837e6db","type":"BasicTickFormatter"},"plot":{"id":"259a60bf-7538-4185-978a-ab4143733bfc","subtype":"Figure","type":"Plot"},"ticker":{"id":"e29fad2a-4c08-4146-8df4-43b11bbbe1c0","type":"BasicTicker"}},"id":"0f41204a-97bc-43fe-b5dc-b7eb809b2a87","type":"LinearAxis"},{"attributes":{"plot":{"id":"dff7e88a-0e7b-4cf5-be5b-ea301b18d78d","subtype":"Figure","type":"Plot"}},"id":"6f302ace-10e3-4dab-b4d8-82d71d118979","type":"PanTool"},{"attributes":{},"id":"8b3381e8-5f22-47e1-a460-c3c4934f6f00","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"dff7e88a-0e7b-4cf5-be5b-ea301b18d78d","subtype":"Figure","type":"Plot"}},"id":"716e4798-ecbc-4862-804b-2450ef1a5949","type":"WheelZoomTool"},{"attributes":{"overlay":{"id":"41c37ec7-9f06-413e-ac58-69f9b27c6372","type":"BoxAnnotation"},"plot":{"id":"dff7e88a-0e7b-4cf5-be5b-ea301b18d78d","subtype":"Figure","type":"Plot"}},"id":"e4a85f01-ea74-4e7a-9feb-7bb025ff728a","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"dff7e88a-0e7b-4cf5-be5b-ea301b18d78d","subtype":"Figure","type":"Plot"}},"id":"aac6b248-8649-4b07-9b01-61155b1d1990","type":"SaveTool"},{"attributes":{"plot":{"id":"dff7e88a-0e7b-4cf5-be5b-ea301b18d78d","subtype":"Figure","type":"Plot"}},"id":"ace67a48-0a72-497b-ae1a-f03e4fe0e4f2","type":"ResetTool"},{"attributes":{"plot":{"id":"dff7e88a-0e7b-4cf5-be5b-ea301b18d78d","subtype":"Figure","type":"Plot"}},"id":"b657ead0-7ede-44a5-af7a-b7a2bda46f38","type":"HelpTool"},{"attributes":{"sizing_mode":"scale_width","toolbar_location":"above","tools":[{"id":"9626e2ea-9f76-48bd-8bff-3f3a3f9c6d59","type":"PanTool"},{"id":"99be37c4-7de1-4052-8f91-5fa9d75d168e","type":"WheelZoomTool"},{"id":"8afba874-e137-44ff-a234-de001634cdb8","type":"BoxZoomTool"},{"id":"38c39145-009e-476e-b562-dc30b24c154a","type":"SaveTool"},{"id":"c97adb83-83b4-4f7e-84c1-686b0627bf88","type":"ResetTool"},{"id":"0d975249-dada-4271-863a-e9a3d25a50a5","type":"HelpTool"},{"id":"84ce8cb1-6989-45fe-aa49-c6bed69f4f7d","type":"PanTool"},{"id":"fa6257ae-f61a-4deb-8eeb-f4bad6e68ce5","type":"WheelZoomTool"},{"id":"aef93a38-ec6e-456d-83c9-23dbf017cbc3","type":"BoxZoomTool"},{"id":"3cfa5519-5c9d-4fd5-ad46-61db927fde4e","type":"SaveTool"},{"id":"e535899b-032d-4530-a16f-3cfda9a216e8","type":"R ...

# %% [markdown]
# ## 2) Pq FMC2 tem menos reprovações pq está entrando menos alunos ?

# %%
listTabs = []
for index, row in pd_disciplinas.iterrows():
    x = ['20140', '20145', '20150', '20155', '20160', '20165', '20170']

    listCount = []
    for count in pd_dados.groupby(['nome_disc', 'ano_periodo'])['total_alunos'].sum()[row['nome_disc']]:
        listCount.append(count)

    p = figure(plot_width=400, plot_height=300, title=row['nome_disc'], x_axis_label='ano/semestre', y_axis_label='Total Matriculados')
    p.line(x, listCount)
    listTabs.append(p)

output_notebook()
grid = gridplot([[ listTabs[0], listTabs[1]],[ listTabs[2], listTabs[3]]])
show(grid)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="37ff75a3-0a42-4314-80fe-09df1e307bd4">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3cef1b62-1495-4c0b-977d-01696f9563fc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("3cef1b62-1495-4c0b-977d-01696f9563fc");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3cef1b62-1495-4c0b-977d-01696f9563fc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3cef1b62-1495-4c0b-977d-01696f9563fc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"58e3be0a-9841-423c-8fc9-26fca18505a8":{"roots":{"references":[{"attributes":{"plot":null,"text":"C\u00c1LCULO DIFERENCIAL E INTEGRAL I"},"id":"5397b061-67f2-43da-ac99-41966f211160","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f07d9554-c2d1-4c4a-b351-aadd9637ce44","type":"PanTool"},{"id":"a335916c-e561-472a-93be-c4f762abf455","type":"WheelZoomTool"},{"id":"2ce319dd-e8c7-45ca-b33c-4464adaf2941","type":"BoxZoomTool"},{"id":"ffa59d7a-98aa-45a7-9de3-2563121e6468","type":"SaveTool"},{"id":"556dcc70-03a0-474a-8817-2235d7466051","type":"ResetTool"},{"id":"8954a0cc-7bf5-4d9d-a2ae-38d75de7dd4e","type":"HelpTool"}]},"id":"bdd2c186-b802-40c8-b64e-5c4135bbb491","type":"Toolbar"},{"attributes":{"callback":null},"id":"b3719760-ad4a-4152-be4b-3296cf9fdcb5","type":"DataRange1d"},{"attributes":{"plot":{"id":"b1e84977-44b9-4d29-aea2-f6e1e58eb27a","subtype":"Figure","type":"Plot"}},"id":"92a963db-723c-4087-a6bc-13966e2a96af","type":"HelpTool"},{"attributes":{},"id":"abae3208-c161-46e8-9920-a4815bda53ba","type":"ToolEvents"},{"attributes":{},"id":"3bcd5564-6774-4c7d-a1c5-ffdb33de7bad","type":"BasicTickFormatter"},{"attributes":{},"id":"0d138161-4e94-4ae4-b38d-cf14acaca13a","type":"ToolEvents"},{"attributes":{"callback":null},"id":"a36b9ca5-c595-407d-bfce-71fa2457a608","type":"DataRange1d"},{"attributes":{"children":[{"id":"f1246da2-c1ab-4e2a-9170-2493d21196ad","type":"Row"},{"id":"a7c0fb0e-0dbe-47a3-900c-532b489b9a56","type":"Row"}]},"id":"a3f2373b-813d-42d6-a221-abeee69ef7d5","type":"Column"},{"attributes":{"plot":{"id":"b1e84977-44b9-4d29-aea2-f6e1e58eb27a","subtype":"Figure","type":"Plot"}},"id":"03bf5a00-5a7a-436f-ac8c-a74f185a0b5b","type":"ResetTool"},{"attributes":{"plot":null,"text":"RESOLU\u00c7\u00c3O DE PROBLEMAS MATEM\u00c1TICOS PARA TI"},"id":"9681788f-7d9a-45e8-bdce-a3d8773f134e","type":"Title"},{"attributes":{"plot":{"id":"b1e84977-44b9-4d29-aea2-f6e1e58eb27a","subtype":"Figure","type":"Plot"}},"id":"fb4fff62-8aae-4cb1-bad8-7f584292d680","type":"WheelZoomTool"},{"attributes":{"children":[{"id":"54a47bf5-06e9-46a1-8379-33b3110c7c24","type":"ToolbarBox"},{"id":"a3f2373b-813d-42d6-a221-abeee69ef7d5","type":"Column"}]},"id":"02caf6cc-8dd6-415e-b228-89b249062db0","type":"Column"},{"attributes":{"overlay":{"id":"e447770a-757e-43d8-a59f-990ef416296c","type":"BoxAnnotation"},"plot":{"id":"b1e84977-44b9-4d29-aea2-f6e1e58eb27a","subtype":"Figure","type":"Plot"}},"id":"43a27e85-fed8-4360-acdf-14f32938a98e","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3d4238c0-87d5-4a10-9412-dd22e1ee5fe9","type":"Line"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"50b5f9df-ca14-4384-b480-da70354673f5","type":"PanTool"},{"id":"68196c7c-8ccc-4b1d-ac56-4b9baa83d76a","type":"WheelZoomTool"},{"id":"dd4fee07-e461-46ad-98e3-ab72cf1ad453","type":"BoxZoomTool"},{"id":"799b1b44-5cd3-4886-839e-24f9d1831a78","type":"SaveTool"},{"id":"66ec3aba-b7d0-4026-b763-abbae8dc00b2","type":"ResetTool"},{"id":"a44aab19-60b5-4443-8c1d-f41ed233686f","type":"HelpTool"}]},"id":"a01d485a-f2fd-44e0-a167-ea3f360dffba","type":"Toolbar"},{"attributes":{"plot":{"id":"4b8d9dbc-feaa-47e5-9d27-da8f5b0d1280","subtype":"Figure","type":"Plot"},"ticker":{"id":"ca26b3b0-c72a-4cec-b791-5ee6d010fd97","type":"BasicTicker"}},"id":"09a2dd23-0c75-49ff-b798-0b16e836d8f0","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"e447770a-757e-43d8-a59f-990ef416296c","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"b1e84977-44b9-4d29-aea2-f6e1e58eb27a","subtype":"Figure","type":"Plot"}},"id":"7ed ...

# %% [markdown]
# ## 3) Vamos deixar tudo numa mesma escala

# %%
listTabsY = []
for index, row in pd_disciplinas.iterrows():
    listCount = []
    for count in pd_dados.groupby(['nome_disc', 'ano_periodo'])['total_alunos'].sum()[row['nome_disc']]:
        listCount.append(count)
    listTabsY.append(listCount)


data = dict(RPMTI = listTabsY[0], C1 = listTabsY[1], FMC1 = listTabsY[2], FMC2 = listTabsY[3], Semestre=x)
df = pd.DataFrame(data)

line = Line(df, y=['RPMTI', 'C1', 'FMC1', 'FMC2'], x='Semestre', dash=['RPMTI', 'C1', 'FMC1', 'FMC2'],
            title="Matriculados por semestre", ylabel='Total de matriculados', xlabel="Ano/Semestre", 
            legend=True, plot_width=800)
output_notebook()
show(line)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c733ca19-5576-453e-9c96-11410b7873e9">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a885403a-8c6c-4a18-b4d6-917f7220d8ff"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a885403a-8c6c-4a18-b4d6-917f7220d8ff");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a885403a-8c6c-4a18-b4d6-917f7220d8ff");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a885403a-8c6c-4a18-b4d6-917f7220d8ff' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7c79eada-4771-452f-acb9-034dc2c37942":{"roots":{"references":[{"attributes":{"axis_label":"Total de matriculados","formatter":{"id":"0ef9209d-531d-4ab9-8e17-0631b53d0a2b","type":"BasicTickFormatter"},"plot":{"id":"b9fbc42f-a81d-43e2-986d-c4ffd7e1dd91","subtype":"Chart","type":"Plot"},"ticker":{"id":"fe6103c1-3cae-4df6-96b7-873331b6a64c","type":"BasicTicker"}},"id":"4c246051-5e6b-4242-8487-d65cf00e1acf","type":"LinearAxis"},{"attributes":{},"id":"0547895b-f2cd-4a04-b20f-fcd764e06883","type":"CategoricalTicker"},{"attributes":{"label":{"value":"FMC1"},"renderers":[{"id":"81079a74-711c-4e79-a261-9ce8665ddc04","type":"GlyphRenderer"}]},"id":"6ffc85b5-1f97-4195-95f5-0c83477662ce","type":"LegendItem"},{"attributes":{"data_source":{"id":"c2a7541e-4b8d-4131-abf6-a1f5d0126228","type":"ColumnDataSource"},"glyph":{"id":"ad104184-c946-47b1-943f-a501569364cd","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"72cc8fbb-15c3-40aa-9bc7-4abe6d16bfae","type":"GlyphRenderer"},{"attributes":{"label":{"value":"C1"},"renderers":[{"id":"ec9671fd-20c6-440a-aaa8-78172ee3d1f6","type":"GlyphRenderer"}]},"id":"a5e95aa3-f0e4-4396-aebd-c301a2f48156","type":"LegendItem"},{"attributes":{"line_color":{"value":"#f22c40"},"line_dash":[2,4,6,4],"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"ad104184-c946-47b1-943f-a501569364cd","type":"Line"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"}],"series":["FMC1","FMC1","FMC1","FMC1","FMC1","FMC1","FMC1"],"x_values":["20140","20145","20150","20155","20160","20165","20170"],"y_values":[116,228,196,309,242,263,264]}},"id":"6b42eb1a-1998-4eb1-b5bb-9659a5953794","type":"ColumnDataSource"},{"attributes":{"callback":null,"factors":["20140","20145","20150","20155","20160","20165","20170"]},"id":"28c3a651-2e1b-47fe-8f54-3d51f4c6848c","type":"FactorRange"},{"attributes":{"plot":{"id":"b9fbc42f-a81d-43e2-986d-c4ffd7e1dd91","subtype":"Chart","type":"Plot"}},"id":"e388d575-0b11-4589-a1c5-828f1c867689","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"b9fbc42f-a81d-43e2-986d-c4ffd7e1dd91","subtype":"Chart","type":"Plot"}},"id":"081eb043-7a70-417c-8dfc-0ef19219b537","type":"PanTool"},{"attributes":{"plot":null,"text":"Matriculados por semestre"},"id":"33edcadf-721e-4ea5-834c-f2bef124d768","type":"Title"},{"attributes":{"below":[{"id":"c68809cf-e3b9-4b36-b183-e877e837a68a","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"4c246051-5e6b-4242-8487-d65cf00e1acf","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"cfd29a02-0a53-4abc-a515-e621973d1e28","type":"BoxAnnotation"},{"id":"72cc8fbb-15c3-40aa-9bc7-4abe6d16bfae","type":"GlyphRenderer"},{"id":"ec9671fd-20c6-440a-aaa8-78172ee3d1f6","type":"GlyphRenderer"},{"id":"81079a74-711c-4e79-a261-9ce8665ddc04","type":"GlyphRenderer"},{"id":"4f013f64-8ce8-41f1-94ae-9c9642e4063e","type":"GlyphRenderer"},{"id":"61d1c817-d0b4-4681-9a62-b435aae59aaf","type":"Legend"},{"id":"c68809cf-e3b9-4b36-b183-e877e837a68a","type":"CategoricalAxis"},{"id":"4c246051-5e6b-4242-8487-d65cf00e1acf","type":"LinearAxis"},{"id":"92521c65-b2ed-440f-abde-366115ec48cf","type":"Grid"},{"id":"94222335-dc27-4083-bb8a-8af0d1a3eef7","type":"Grid"}],"title":{"id":"33edcadf-721e-4ea5-834c-f2bef124d768","type":"Title"},"tool_events":{"id":"2e063810-ca24-4b3b-b0f1-8ccc0ca39c10","type":"ToolEvents"},"toolbar":{"id":"590af908-f8a5-4e9d-a2ea-5b97e548f87c","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"28c3a651-2e1b-47fe-8f54-3d51f4c6848c","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"8613f7fc-892a-450b-b386-1b5320248658","type":"Range1d"}},"id":"b9fbc42f-a81d-43e2-986d-c4ffd7e1dd91","subtype":"Chart","type":"Plot"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"FMC2"},{"series":"FMC2"},{"s ...

# %% [markdown]
# ## 4) Qual a porcentagem de reprovação da galera ?

# %%
listAlunos = []
listRep = []
for index, row in pd_disciplinas.iterrows():
    listTotalAlunos = []
    listTotalReprovados = []
    
    for totalAlunos in pd_dados.groupby(['nome_disc', 'ano_periodo'])['total_alunos'].sum()[row['nome_disc']]:
        listTotalAlunos.append(totalAlunos)
        
    for totalRep in pd_dados.groupby(['nome_disc', 'ano_periodo'])['reprovados'].sum()[row['nome_disc']]:
        listTotalReprovados.append(totalRep)
        
    listAlunos.append(listTotalAlunos)
    listRep.append(listTotalReprovados)

listTabsY = []
for apro, rep in zip(listAlunos, listRep):
    listTabsYAux = []
    for i in range(len(apro)):
        listTabsYAux.append((rep[i]/apro[i])*100)
    listTabsY.append(listTabsYAux)
    
data = dict(RPMTI = listTabsY[0], C1 = listTabsY[1], FMC1 = listTabsY[2], FMC2 = listTabsY[3], Semestre=x)
df = pd.DataFrame(data)

line = Line(df, y=['RPMTI', 'C1', 'FMC1', 'FMC2'], x='Semestre', dash=['RPMTI', 'C1', 'FMC1', 'FMC2'],
            title="% de reprovados por disciplina", ylabel='Taxa de reprovados', xlabel="Ano/Semestre", 
            legend=True, plot_width=800)
output_notebook()
show(line)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bffa6c72-2124-40ee-926a-5dad181d90c7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="395fab9b-d04b-44d9-9d44-d2da75bc4d68"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("395fab9b-d04b-44d9-9d44-d2da75bc4d68");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("395fab9b-d04b-44d9-9d44-d2da75bc4d68");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '395fab9b-d04b-44d9-9d44-d2da75bc4d68' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"6ef01c41-706c-4ef9-aca9-0d9d50e78639":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"505df524-b191-4fd7-9dfd-237f18b6c773","type":"PanTool"},{"id":"2797b187-f5af-49e0-8620-f223ac05c474","type":"WheelZoomTool"},{"id":"a1c1608f-f33b-4d5d-bb6b-de78a2239021","type":"BoxZoomTool"},{"id":"d2247738-3ac5-4807-a828-e8a922169bfd","type":"SaveTool"},{"id":"22167b61-775d-4ae7-96b3-3f99c1f0baa7","type":"ResetTool"},{"id":"0dce549c-ba72-431d-b90f-9ea60b18e894","type":"HelpTool"}]},"id":"f295c238-3eb5-499c-ac39-47ea9ea935a8","type":"Toolbar"},{"attributes":{"plot":{"id":"1d5991d7-2027-447e-b35a-9eaa9806d421","subtype":"Chart","type":"Plot"}},"id":"22167b61-775d-4ae7-96b3-3f99c1f0baa7","type":"ResetTool"},{"attributes":{"line_color":{"value":"#f22c40"},"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"42378665-f7e2-4fd2-962d-d4a815a1b045","type":"Line"},{"attributes":{"plot":{"id":"1d5991d7-2027-447e-b35a-9eaa9806d421","subtype":"Chart","type":"Plot"}},"id":"505df524-b191-4fd7-9dfd-237f18b6c773","type":"PanTool"},{"attributes":{"plot":{"id":"1d5991d7-2027-447e-b35a-9eaa9806d421","subtype":"Chart","type":"Plot"},"ticker":{"id":"dd7c6419-486f-40ce-b216-5c26fbc73393","type":"CategoricalTicker"}},"id":"b90a56f4-d9ce-41f6-96fc-dbaaa84ebeb2","type":"Grid"},{"attributes":{"plot":{"id":"1d5991d7-2027-447e-b35a-9eaa9806d421","subtype":"Chart","type":"Plot"}},"id":"d2247738-3ac5-4807-a828-e8a922169bfd","type":"SaveTool"},{"attributes":{"label":{"value":"FMC2"},"renderers":[{"id":"c5577567-2856-4cbd-a07d-7658866c9d88","type":"GlyphRenderer"}]},"id":"57c9260a-b0b1-447b-a51b-567a1cfe4360","type":"LegendItem"},{"attributes":{"data_source":{"id":"097aa525-c6e5-4699-b344-d9b263634b46","type":"ColumnDataSource"},"glyph":{"id":"42378665-f7e2-4fd2-962d-d4a815a1b045","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"3f1adef2-1b8a-4650-91d9-b3199db84b5e","type":"GlyphRenderer"},{"attributes":{},"id":"7a958d36-b0bc-4242-bcfa-87f039cc5220","type":"BasicTickFormatter"},{"attributes":{"line_color":{"value":"#f22c40"},"line_dash":[2,4,6,4],"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"5bc329b0-ad78-4f28-8bf1-ad8965720136","type":"Line"},{"attributes":{},"id":"66c37fce-2a61-46a0-95da-15ead2eefe2f","type":"CategoricalTickFormatter"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"C1"},{"series":"C1"},{"series":"C1"},{"series":"C1"},{"series":"C1"},{"series":"C1"},{"series":"C1"}],"series":["C1","C1","C1","C1","C1","C1","C1"],"x_values":["20140","20145","20150","20155","20160","20165","20170"],"y_values":{"__ndarray__":"Pc/zPM/zTkBT5LNuMEVUQDaU11Bew1FAt23btm3bUUCYDZp82SBVQLZywjP9DU5A4ziO4zgOUkA=","dtype":"float64","shape":[7]}}},"id":"097aa525-c6e5-4699-b344-d9b263634b46","type":"ColumnDataSource"},{"attributes":{"label":{"value":"RPMTI"},"renderers":[{"id":"740c9def-db74-4823-b1d8-15bae4a1b4a8","type":"GlyphRenderer"}]},"id":"8f96f828-5590-4a98-ba72-7697684f9ff8","type":"LegendItem"},{"attributes":{"label":{"value":"C1"},"renderers":[{"id":"3f1adef2-1b8a-4650-91d9-b3199db84b5e","type":"GlyphRenderer"}]},"id":"643d03dc-a46a-426e-be53-09dfa33d6193","type":"LegendItem"},{"attributes":{"line_color":{"value":"#f22c40"},"line_dash":[6],"line_width":{"value":2},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"f0ef4b12-68f3-4340-b220-be87db63450b","type":"Line"},{"attributes":{"below":[{"id":"7b369839-ed70-4a69-bd0b-496231583aa7","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"1271a615-fea4-48a5-b652-c8b9a31b56a7","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"e9f1d8be-7a90-4f7b-8b80-b23194566b0d","type":"BoxAnnotation"},{"id":"740c9def-db74-4823-b1d8-15bae4a1b4a8","type":"GlyphRenderer"},{"id":"3f1adef2-1b8a-4650-91d9-b3199db84b5e","type":"GlyphRenderer"},{"id":"e67723f0-4954-4c28-b9d3-e06e0d2ddee2","type":"Glyph ...

# %% [markdown]
# ## 5) Quais professores estão gerando mais reprovações?

# %%
((pd_dados.groupby(['nome_prof'])['reprovados'].sum()/pd_dados.groupby(['nome_prof'])['total_alunos'].sum())*100).sort_values().plot(kind='bar', figsize=(18, 10))

# %%
((pd_dados.groupby(['nome_prof'])['reprovados'].sum()/pd_dados.groupby(['nome_prof'])['total_alunos'].sum())*100).sort_values()
# Out:
# nome_prof
# AUGUSTO JORGE DE MACEDO                50.526316
# ALYSON MATHEUS DE CARVALHO SOUZA       54.802260
# CHARLES ANDRYE GALVAO MADEIRA          59.927798
# vazio                                  67.566607
# ANTONIO IGOR SILVA DE OLIVEIRA         70.976253
# RAFAELA HORACINA SILVA ROCHA SOARES    71.834061
# REGIVAN HUGO NUNES SANTIAGO            73.142857
# LOURENA KARIN DE MEDEIROS ROCHA        74.866310
# ADJA FERREIRA DE ANDRADE               75.000000
# ANDERSON PAIVA CRUZ                    75.681342
# SAMYR SILVA BEZERRA JACOME             76.923077
# UMBERTO RIVIECCIO                      78.021978
# JOAO MARCOS DE ALMEIDA                 82.051282
# CARLOS AUGUSTO PROLO                   83.445190
# ATHANASIOS TSOUANAS                    89.096573
# dtype: float64
