# %%
import pandas as pd
import seaborn as sns
from bokeh.charts import Line
from bokeh.layouts import gridplot, row
from bokeh.plotting import figure, output_notebook, show
# %matplotlib inline

# %%
pd_dados = pd.read_csv('turma_professor_notas.csv')
pd_disciplinas = pd.read_csv('disciplinas.csv')

# %% [markdown]
# ## 1) Notas das turmas tem muita diferença entre um mesmo semestre?

# %%
listTabs = []
for index, row in pd_disciplinas.iterrows():
    
    y = pd_dados[pd_dados['nome_disc'] == row['nome_disc']]['reprovados']
    x = []
    for index_disc, row_disc in pd_dados[pd_dados['nome_disc'] == row['nome_disc']].iterrows():
        if (int(row_disc['periodo']) == 1):
            x.append(str(row_disc['ano'])+""+str(0))
        else:
           x.append(str(row_disc['ano'])+""+str(5))
        
    p = figure(plot_width=400, plot_height=300, y_range=(0, 100), title=row['nome_disc'], x_axis_label='ano/semestre', y_axis_label='Quant Reprovados')
    p.circle(x, y, fill_color="white", size=12,)
    listTabs.append(p)

output_notebook()
grid = gridplot([[ listTabs[0], listTabs[1]],[ listTabs[2], listTabs[3]]])
show(grid)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2900e940-353a-49be-b728-7e2f216ce3aa">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="efb486d5-fc74-48c6-8e14-c9a980ecabf8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("efb486d5-fc74-48c6-8e14-c9a980ecabf8");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("efb486d5-fc74-48c6-8e14-c9a980ecabf8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'efb486d5-fc74-48c6-8e14-c9a980ecabf8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4964fed0-4426-4009-9838-813c7a865902":{"roots":{"references":[{"attributes":{"plot":null,"text":"FUNDAMENTOS MATEM\u00c1TICOS DA COMPUTA\u00c7\u00c3O I"},"id":"7d936b0f-c2c0-4450-9962-0fe6d9c02bb3","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"72d8a456-208b-4b79-856a-999f91164aa4","type":"Circle"},{"attributes":{"callback":null},"id":"cf948c0f-46de-460c-9aad-9b0e70df6bad","type":"DataRange1d"},{"attributes":{},"id":"899dcd3d-8ad8-4144-8b70-540563777393","type":"BasicTicker"},{"attributes":{"plot":{"id":"b85ac599-f560-4c98-bb39-1b50594e285a","subtype":"Figure","type":"Plot"},"ticker":{"id":"899dcd3d-8ad8-4144-8b70-540563777393","type":"BasicTicker"}},"id":"242b86f6-7e1f-4af5-b170-8931ab231f26","type":"Grid"},{"attributes":{"axis_label":"Quant Reprovados","formatter":{"id":"1112c1d7-a272-4f08-b5bf-bdb9f848c948","type":"BasicTickFormatter"},"plot":{"id":"b85ac599-f560-4c98-bb39-1b50594e285a","subtype":"Figure","type":"Plot"},"ticker":{"id":"732f0213-186d-4f6e-9de7-5e87afddbdec","type":"BasicTicker"}},"id":"6068a425-3282-41f7-8513-46da3ceaef28","type":"LinearAxis"},{"attributes":{},"id":"732f0213-186d-4f6e-9de7-5e87afddbdec","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"b85ac599-f560-4c98-bb39-1b50594e285a","subtype":"Figure","type":"Plot"},"ticker":{"id":"732f0213-186d-4f6e-9de7-5e87afddbdec","type":"BasicTicker"}},"id":"5afbb753-f5ae-4687-a4d4-b1d0309869c3","type":"Grid"},{"attributes":{"data_source":{"id":"f913ffa9-e9e9-4b49-b425-d417ddd2c0fe","type":"ColumnDataSource"},"glyph":{"id":"4c2e0a13-ae30-403c-a6d4-961eb24479da","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"72d8a456-208b-4b79-856a-999f91164aa4","type":"Circle"},"selection_glyph":null},"id":"e6dc11b6-e713-4f78-ab70-fd02b6b517d3","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"white"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":12},"x":{"field":"x"},"y":{"field":"y"}},"id":"4c2e0a13-ae30-403c-a6d4-961eb24479da","type":"Circle"},{"attributes":{"callback":null},"id":"50d4dc7b-3484-4c49-875f-e70331a95781","type":"DataRange1d"},{"attributes":{},"id":"1112c1d7-a272-4f08-b5bf-bdb9f848c948","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a5ba1e21-5f1d-487c-b3bb-99ca5ac232a2","type":"BoxAnnotation"},{"attributes":{"axis_label":"ano/semestre","formatter":{"id":"edf91cff-3e59-4dd4-a70f-dd8dc58f1099","type":"BasicTickFormatter"},"plot":{"id":"b06d8bdc-4c18-41dd-9cf1-7aea90fa049b","subtype":"Figure","type":"Plot"},"ticker":{"id":"3b4f91fa-8664-45e6-976c-391f819d89b5","type":"BasicTicker"}},"id":"1454c8d8-6651-4f15-b32f-0383c5784df3","type":"LinearAxis"},{"attributes":{"plot":{"id":"b85ac599-f560-4c98-bb39-1b50594e285a","subtype":"Figure","type":"Plot"}},"id":"3a4741ce-3eaa-4a56-9577-bd2d5a1da600","type":"PanTool"},{"attributes":{},"id":"b50c2ecc-4d95-4bc5-8f2b-7976a0d56bca","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5b5abd8e-23a0-4d0f-968f-b836c0a49dbd","type":"PanTool"},{"id":"34873ad5-9f83-4c0b-8b7d-23f8d7dbffb7","type":"WheelZoomTool"},{"id":"a4d00a57-40c9-4a4a-a5f6-56c2d7d1f7e7","type":"BoxZoomTool"},{"id":"3f9a3d7a-0d36-4ed1-a860-a9fd6bbfd084","type":"SaveTool"},{"id":"aed6f776-dba2-4a40-85e0-bb4a4de9e772","type":"ResetTool"},{"id":"4faad85d-a1d2-4059-bf88-b0573a333401","type":"HelpTool"}]},"id":"6026178e-04a0-4dc7-99c8-9c9ed47bbacd","type":"Toolbar"},{"attributes":{},"id":"94ff299c-34d2-44fe-9f57-37819 ...

# %% [markdown]
# ## 2) FMC2 tem menos reprovações pq tem menos pessoas matriculadas ?

# %%
listTabs = []
for index, row in pd_disciplinas.iterrows():
    x = ['20140', '20145', '20150', '20155', '20160', '20165', '20170']

    listCount = []
    for count in pd_dados.groupby(['nome_disc', 'ano_periodo'])['total_alunos'].sum()[row['nome_disc']]:
        listCount.append(count)

    p = figure(plot_width=400, plot_height=300, y_range=(0, 1000), title=row['nome_disc'], x_axis_label='ano/semestre', y_axis_label='Total Matriculados')
    p.line(x, listCount)
    listTabs.append(p)

output_notebook()
grid = gridplot([[ listTabs[0], listTabs[1]],[ listTabs[2], listTabs[3]]])
show(grid)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2567a221-a3fd-435c-b00b-00e210de3bd1">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bf7ca104-b1ee-43c4-8678-750b3760e16f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("bf7ca104-b1ee-43c4-8678-750b3760e16f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bf7ca104-b1ee-43c4-8678-750b3760e16f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bf7ca104-b1ee-43c4-8678-750b3760e16f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"488b7d7e-6eed-492d-a8d0-b4431eef8b66":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"cf4f92b2-ad66-4df5-b541-ef45c2f23c8f","subtype":"Figure","type":"Plot"},"ticker":{"id":"15d5ed90-f3fb-4115-bb9a-b46d31ee4dfb","type":"BasicTicker"}},"id":"b6b11fa2-ad7c-4a24-98fc-956bb5e87891","type":"Grid"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb293d6d-8872-4664-b34b-61711ed8235e","type":"Line"},{"attributes":{"data_source":{"id":"24c00da0-8c6e-4735-9967-f82d14722875","type":"ColumnDataSource"},"glyph":{"id":"ae443510-ba54-49b2-8643-7bc2abdc3e45","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"bb293d6d-8872-4664-b34b-61711ed8235e","type":"Line"},"selection_glyph":null},"id":"a4f1ec95-abff-4fef-a6ec-d22992c30b3e","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":["20140","20145","20150","20155","20160","20165","20170"],"y":[42,111,190,252,226,183,144]}},"id":"21cbe4b2-7c4a-4cf3-8104-f13277591317","type":"ColumnDataSource"},{"attributes":{"below":[{"id":"3b9f701b-1ea9-4486-a24a-7d021432df31","type":"LinearAxis"}],"left":[{"id":"fc244026-377c-47fe-81e1-4b5993d2d9b8","type":"LinearAxis"}],"plot_height":300,"plot_width":400,"renderers":[{"id":"3b9f701b-1ea9-4486-a24a-7d021432df31","type":"LinearAxis"},{"id":"ead1205c-1d9b-48de-9602-0d21a38551d8","type":"Grid"},{"id":"fc244026-377c-47fe-81e1-4b5993d2d9b8","type":"LinearAxis"},{"id":"23a91be2-61dc-49f5-b1f6-3830fd234daf","type":"Grid"},{"id":"cca37455-6d34-4ba9-8095-dd0bbed4dee5","type":"BoxAnnotation"},{"id":"a4f1ec95-abff-4fef-a6ec-d22992c30b3e","type":"GlyphRenderer"}],"title":{"id":"0e7e61ed-0fc9-429a-a952-09a83f69b3a5","type":"Title"},"tool_events":{"id":"a7d5149f-887c-4341-b238-13a8d1aebcd2","type":"ToolEvents"},"toolbar":{"id":"5803dc65-2b24-4a3b-8591-a306221bb78a","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"f42e2648-43c4-4283-af76-17fd6651210b","type":"DataRange1d"},"y_range":{"id":"dcbc6bb9-3487-42ec-a853-a0acc66aae2e","type":"Range1d"}},"id":"068a4ecf-d28f-438d-9aa2-e164d8e82c26","subtype":"Figure","type":"Plot"},{"attributes":{"children":[{"id":"96113766-8975-4381-9e79-37398bec8cd3","type":"Row"},{"id":"5587f1e9-4527-4414-bb2c-14dd3120db9e","type":"Row"}]},"id":"4910dc4b-6e8c-428d-a20d-acd7d8444ce3","type":"Column"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":["20140","20145","20150","20155","20160","20165","20170"],"y":[584,82,590,272,764,372,950]}},"id":"24c00da0-8c6e-4735-9967-f82d14722875","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"96b54d22-59e1-4d32-8d6b-e47d54e7204a","subtype":"Figure","type":"Plot"}},"id":"c0d00ac7-542e-4c4c-bd73-b872711c2286","type":"SaveTool"},{"attributes":{"dimension":1,"plot":{"id":"96b54d22-59e1-4d32-8d6b-e47d54e7204a","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb024513-f0f9-4b13-ac7a-9c8a1ed1322e","type":"BasicTicker"}},"id":"9c3b836f-01c3-4f2d-99c9-3bef3d6f30ff","type":"Grid"},{"attributes":{"plot":{"id":"96b54d22-59e1-4d32-8d6b-e47d54e7204a","subtype":"Figure","type":"Plot"}},"id":"2e859cc2-cc53-4aaf-9e24-acce03f0d559","type":"ResetTool"},{"attributes":{"children":[{"id":"068a4ecf-d28f-438d-9aa2-e164d8e82c26","subtype":"Figure","type":"Plot"},{"id":"96b54d22-59e1-4d32-8d6b-e47d54e7204a","subtype":"Figure","type":"Plot"}]},"id":"96113766-8975-4381-9e79-37398bec8cd3","type":"Row"},{"attributes":{"plot":null,"text":"FUNDAMENTOS MATEM\u00c1TICOS DA COMPUTA\u00c7\u00c3O I"},"id":"d178ac08-0ab4-4b8c-a10c-a7ece12f58e2","type":"Title"},{"attributes":{"plot":null,"text":"RESOLU\u00c7\u00c3O DE PROBLEMAS MATEM\u00c1TICOS PARA TI"},"id":"0e7e61ed-0fc9-429a-a952-09a83f69b3a5","type":"Title"},{"attributes":{"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"7c7aa12d-a04e-4051-b412-28dcc08f859a","type":"Line"},{"attributes":{"data_source":{"id":"88ddbd86-9a3b-4852-a402-ee0830d73c1f","t ...

# %% [markdown]
# ## 3) Vamos juntar esses gráficos para comparar melhor

# %%
listTabsY = []
for index, row in pd_disciplinas.iterrows():
    listCount = []
    for count in pd_dados.groupby(['nome_disc', 'ano_periodo'])['total_alunos'].sum()[row['nome_disc']]:
        listCount.append(count)
    listTabsY.append(listCount)


data = dict(RPMTI = listTabsY[0], C1 = listTabsY[1], FMC1 = listTabsY[2], FMC2 = listTabsY[3], Semestre=x)
df = pd.DataFrame(data)

line = Line(df, y=['RPMTI', 'C1', 'FMC1', 'FMC2'], x='Semestre', dash=['RPMTI', 'C1', 'FMC1', 'FMC2'],
            title="Matriculados por semestre", ylabel='Total de matriculados', xlabel="Ano/Semestre", 
            legend=True, plot_width=800)
output_notebook()
show(line)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="813e98fb-c49e-4be7-a77b-f1b365b6a9a8">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6da26615-462c-4b82-abb3-2eef3d50c09d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("6da26615-462c-4b82-abb3-2eef3d50c09d");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6da26615-462c-4b82-abb3-2eef3d50c09d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6da26615-462c-4b82-abb3-2eef3d50c09d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e2b8a3eb-b354-4685-a8d8-42a90fa17bde":{"roots":{"references":[{"attributes":{"items":[{"id":"8cc14956-69b8-47f8-b0ba-b47aa3cee68c","type":"LegendItem"},{"id":"af394e4f-fb62-48a4-88ce-39066196407f","type":"LegendItem"},{"id":"a87988b1-fabf-4cb4-b504-b15d43b50424","type":"LegendItem"},{"id":"6ed8ef19-c5ce-4082-8f76-509979924075","type":"LegendItem"}],"location":"top_left","plot":{"id":"9c651b63-991e-4d4d-a54e-6fb666291141","subtype":"Chart","type":"Plot"}},"id":"3cd014ba-c980-4ee1-9c51-988534deca2e","type":"Legend"},{"attributes":{"callback":null,"end":1041.7,"start":-58.7},"id":"eda987a4-e1de-435c-8d2a-edc2aa34cc0c","type":"Range1d"},{"attributes":{"overlay":{"id":"2e0d5679-e8f0-4df0-84d3-bce856987c16","type":"BoxAnnotation"},"plot":{"id":"9c651b63-991e-4d4d-a54e-6fb666291141","subtype":"Chart","type":"Plot"}},"id":"528ce512-6ce0-484a-befb-f0b69feda1df","type":"BoxZoomTool"},{"attributes":{"axis_label":"Ano/Semestre","formatter":{"id":"8a8d95c3-4ed9-4f3b-9c91-addc5f6221e5","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"9c651b63-991e-4d4d-a54e-6fb666291141","subtype":"Chart","type":"Plot"},"ticker":{"id":"7b1e8ea9-6ed7-4ba5-aded-7262384b9b90","type":"CategoricalTicker"}},"id":"5e3abc65-1513-4534-b75d-4ccf14455b1d","type":"CategoricalAxis"},{"attributes":{"label":{"value":"C1"},"renderers":[{"id":"05ca0dd5-9129-4e75-8f0f-09008283b369","type":"GlyphRenderer"}]},"id":"af394e4f-fb62-48a4-88ce-39066196407f","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"}],"series":["RPMTI","RPMTI","RPMTI","RPMTI","RPMTI","RPMTI","RPMTI"],"x_values":["20140","20145","20150","20155","20160","20165","20170"],"y_values":[584,82,590,272,764,372,950]}},"id":"382110ff-cf5d-400d-b10f-3579dbc7b1ca","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"60e60bcb-9691-41fa-82a3-ccb99f988ad4","type":"ColumnDataSource"},"glyph":{"id":"ee7beb1a-586f-4597-98f4-94f035a4cf44","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"455e7a40-4eb3-419e-baa7-c50fec818c53","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"}],"series":["FMC2","FMC2","FMC2","FMC2","FMC2","FMC2","FMC2"],"x_values":["20140","20145","20150","20155","20160","20165","20170"],"y_values":[33,78,95,90,135,150,107]}},"id":"bc19afbb-9362-400a-b1df-41b939395875","type":"ColumnDataSource"},{"attributes":{"label":{"value":"RPMTI"},"renderers":[{"id":"63d77671-808b-46f3-b9d8-a514ade08004","type":"GlyphRenderer"}]},"id":"8cc14956-69b8-47f8-b0ba-b47aa3cee68c","type":"LegendItem"},{"attributes":{"dimension":1,"plot":{"id":"9c651b63-991e-4d4d-a54e-6fb666291141","subtype":"Chart","type":"Plot"},"ticker":{"id":"6cea31c3-1811-49d2-9b9a-3a1493f84bf2","type":"BasicTicker"}},"id":"0caffd5a-22b6-4d2a-8c14-b1ebdf041d8d","type":"Grid"},{"attributes":{"callback":null,"factors":["20140","20145","20150","20155","20160","20165","20170"]},"id":"f62e5f40-f821-4839-a9ee-b7195c8b16f0","type":"FactorRange"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"2e0d5679-e8f0-4df0-84d3-bce856987c16","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"},{"series":"FMC1"}],"series":["FMC1","FMC1","FMC1","FMC1","FMC1","FMC1","F ...

# %% [markdown]
# ## 4) Qual a porcentagem de reprovação da galera ?

# %%
listAlunos = []
listRep = []
for index, row in pd_disciplinas.iterrows():
    listTotalAlunos = []
    listTotalReprovados = []
    
    for totalAlunos in pd_dados.groupby(['nome_disc', 'ano_periodo'])['total_alunos'].sum()[row['nome_disc']]:
        listTotalAlunos.append(totalAlunos)
        
    for totalRep in pd_dados.groupby(['nome_disc', 'ano_periodo'])['reprovados'].sum()[row['nome_disc']]:
        listTotalReprovados.append(totalRep)
        
    listAlunos.append(listTotalAlunos)
    listRep.append(listTotalReprovados)

listTabsY = []
for apro, rep in zip(listAlunos, listRep):
    listTabsYAux = []
    for i in range(len(apro)):
        listTabsYAux.append((rep[i]/apro[i])*100)
    listTabsY.append(listTabsYAux)
    
data = dict(RPMTI = listTabsY[0], C1 = listTabsY[1], FMC1 = listTabsY[2], FMC2 = listTabsY[3], Semestre=x)
df = pd.DataFrame(data)

line = Line(df, y=['RPMTI', 'C1', 'FMC1', 'FMC2'], x='Semestre', dash=['RPMTI', 'C1', 'FMC1', 'FMC2'],
            title="% de reprovados por disciplina", ylabel='Taxa de reprovados', xlabel="Ano/Semestre", 
            legend=True, plot_width=800)

output_notebook()
show(line)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="abefb3c0-447f-4c14-9476-84adeb9ad4e3">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a0e7e9b9-d19f-45d8-8950-623e4133f1c9"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a0e7e9b9-d19f-45d8-8950-623e4133f1c9");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a0e7e9b9-d19f-45d8-8950-623e4133f1c9");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a0e7e9b9-d19f-45d8-8950-623e4133f1c9' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"b1b635ff-00e6-474c-ab0b-05f4a8a72082":{"roots":{"references":[{"attributes":{"callback":null,"end":93.6326109391125,"start":33.19917440660475},"id":"51135f07-c7b7-4ba6-81a5-2bbfe32490f7","type":"Range1d"},{"attributes":{"dimension":1,"plot":{"id":"edbcecac-0951-44c7-ac86-cde272abb435","subtype":"Chart","type":"Plot"},"ticker":{"id":"424a1e7d-4391-48b7-8868-8961aebbc89d","type":"BasicTicker"}},"id":"cd6a1cdf-b452-4b77-9a6c-dfb9cebbd1b3","type":"Grid"},{"attributes":{"plot":{"id":"edbcecac-0951-44c7-ac86-cde272abb435","subtype":"Chart","type":"Plot"},"ticker":{"id":"c8740472-1329-4357-a6eb-2a4984d22c86","type":"CategoricalTicker"}},"id":"e5d4be76-3804-4569-b750-2537f890c3d2","type":"Grid"},{"attributes":{},"id":"bce6d76a-761c-4a71-b04a-33ecddf265a0","type":"CategoricalTickFormatter"},{"attributes":{"label":{"value":"RPMTI"},"renderers":[{"id":"b8dbf5d4-c01c-4f0b-adee-c52c4c6bb39d","type":"GlyphRenderer"}]},"id":"812d12e3-5656-4f1a-8438-740c2ae99795","type":"LegendItem"},{"attributes":{},"id":"335360c6-ad5c-47e1-8c44-ec779a913a49","type":"BasicTickFormatter"},{"attributes":{"below":[{"id":"9848f512-9d4a-421d-9fd4-c247c178e2ae","type":"CategoricalAxis"}],"css_classes":null,"left":[{"id":"2237cc14-2dd8-4e59-9d06-a21e79cc83ef","type":"LinearAxis"}],"plot_width":800,"renderers":[{"id":"07c3fd11-acf8-4f75-98ac-8ffc5884cf4d","type":"BoxAnnotation"},{"id":"b8dbf5d4-c01c-4f0b-adee-c52c4c6bb39d","type":"GlyphRenderer"},{"id":"e14dde1a-0a05-4f7f-bce5-300237f3ba16","type":"GlyphRenderer"},{"id":"e8f3a521-a642-470c-b775-0fe69ee080e7","type":"GlyphRenderer"},{"id":"6926d409-404d-4b14-ade3-bb6064e91a16","type":"GlyphRenderer"},{"id":"8e1b373f-c123-42b5-950a-5697ca623675","type":"Legend"},{"id":"9848f512-9d4a-421d-9fd4-c247c178e2ae","type":"CategoricalAxis"},{"id":"2237cc14-2dd8-4e59-9d06-a21e79cc83ef","type":"LinearAxis"},{"id":"e5d4be76-3804-4569-b750-2537f890c3d2","type":"Grid"},{"id":"cd6a1cdf-b452-4b77-9a6c-dfb9cebbd1b3","type":"Grid"}],"title":{"id":"b8fc9032-1fa6-4243-a887-2d39b87c025d","type":"Title"},"tool_events":{"id":"adbdf5b9-0fa4-4c34-a043-9d46d3a0cbf8","type":"ToolEvents"},"toolbar":{"id":"49bd9551-90a6-46bb-8752-f2f7f13e3472","type":"Toolbar"},"x_mapper_type":"auto","x_range":{"id":"3134f98b-d0e1-4015-9fd9-4fa256c40b72","type":"FactorRange"},"y_mapper_type":"auto","y_range":{"id":"51135f07-c7b7-4ba6-81a5-2bbfe32490f7","type":"Range1d"}},"id":"edbcecac-0951-44c7-ac86-cde272abb435","subtype":"Chart","type":"Plot"},{"attributes":{"label":{"value":"C1"},"renderers":[{"id":"e14dde1a-0a05-4f7f-bce5-300237f3ba16","type":"GlyphRenderer"}]},"id":"4ef5e983-8f82-4a96-966d-bc2de05aa7a9","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"},{"series":"RPMTI"}],"series":["RPMTI","RPMTI","RPMTI","RPMTI","RPMTI","RPMTI","RPMTI"],"x_values":["20140","20145","20150","20155","20160","20165","20170"],"y_values":{"__ndarray__":"UaFChQoVTECvRO1K1K5RQH55bEXQcEpAHh4eHh4eQ0BhSLaI5ixTQC+77LLLrlJA2FBeQ3kNUEA=","dtype":"float64","shape":[7]}}},"id":"883fa69b-4551-4d3a-ba9c-1994d28ec673","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"},{"series":"FMC2"}],"series":["FMC2","FMC2","FMC2","FMC2","FMC2","FMC2","FMC2"],"x_values":["20140","20145","20150","20155","20160","20165","20170"],"y_values":{"__ndarray__":"bbLJJptsUUCQBmmQBulSQIfyGsprKFJAVVVVVVVVUkAT2ktoL6FTQKqqqqqqKlRA4yMT6J26VUA=","dtype":"float64","shape":[7]}}},"id":"1d832714-cac7-435f-8a00-2ce166d62e54","type":"ColumnDataSource"},{"attributes":{"label":{"value":"FMC1"},"renderers":[{"id":"e8f3a521-a642-470c-b775-0fe69ee080e7","type":"GlyphRenderer"}]},"id":"a4624457-e094-4e2a-925a-90cc786962b2","type":"LegendItem"},{"attribut ...

# %% [markdown]
# ## 5) Quais professores estão gerando mais reprovações?

# %%
((pd_dados.groupby(['nome_prof'])['reprovados'].sum()/pd_dados.groupby(['nome_prof'])['total_alunos'].sum())*100).sort_values()
# Out:
# nome_prof
# AUGUSTO JORGE DE MACEDO                50.526316
# ALYSON MATHEUS DE CARVALHO SOUZA       54.802260
# CHARLES ANDRYE GALVAO MADEIRA          59.927798
# vazio                                  67.566607
# ANTONIO IGOR SILVA DE OLIVEIRA         70.976253
# RAFAELA HORACINA SILVA ROCHA SOARES    71.834061
# REGIVAN HUGO NUNES SANTIAGO            73.142857
# LOURENA KARIN DE MEDEIROS ROCHA        74.866310
# ADJA FERREIRA DE ANDRADE               75.000000
# ANDERSON PAIVA CRUZ                    75.681342
# SAMYR SILVA BEZERRA JACOME             76.923077
# UMBERTO RIVIECCIO                      78.021978
# JOAO MARCOS DE ALMEIDA                 82.051282
# CARLOS AUGUSTO PROLO                   83.445190
# ATHANASIOS TSOUANAS                    89.096573
# dtype: float64

# %%
((pd_dados.groupby(['nome_prof'])['reprovados'].sum()/pd_dados.groupby(['nome_prof'])['total_alunos'].sum())*100).sort_values().plot(kind='bar', figsize=(18, 10))
